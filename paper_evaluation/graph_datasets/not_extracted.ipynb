# %% [markdown]
# # PackGenome

# %%
from collections import Counter

not_extracted_packgenome_lpd = ['Themida_V237_ComIntRep_protect_secureEngine_packed.exe',
 'Themida_V237_geek_protect_secureEngine_packed.exe',
 'Themida_V237_autorunsc_protect_secureEngine_packed.exe',
 'Themida_V237_disk2vhd_protect_secureEngine_packed.exe',
 'Themida_V237_DiskView_protect_secureEngine_packed.exe',
 'Themida_V237_disk2vhd_protect_resources_packed.exe',
 'Themida_V237_cpuz_x32_protect_resources_packed.exe',
 'Themida_V237_ADInsight_protect_secureEngine_packed.exe',
 'Themida_V237_Everything_protect_secureEngine_packed.exe',
 'Themida_V237_Autoruns_protect_secureEngine_packed.exe',
 'Themida_V237_Bginfo_protect_resources_packed.exe',
 'Themida_V237_adwcleaner_7_protect_secureEngine_packed.exe',
 'Themida_V237_cpuz_x32_protect_secureEngine_packed.exe',
 'VMProtect_V246_contrast-normalize_best_packed.exe',
 'VMProtect_V246_edge_best_packed.exe',
 'Armadillo_V800_Autoruns_better.exe',
 'Armadillo_V700_checkver_minimal.exe',
 'Armadillo_V800_ditrace_better.exe',
 'Armadillo_V700_Clockres_best_full.exe',
 'Armadillo_V700_fsquirt_best_resources.exe',
 'Armadillo_V700_DriveCleanup_best_full.exe',
 'Armadillo_V800_ExtExport_better.exe',
 'Armadillo_V700_ftp_best_full.exe',
 'Armadillo_V800_CheckUpdate_better.exe',
 'Armadillo_V800_cleanupintlcache_best_resources.exe',
 'Armadillo_V700_cmd_better.exe',
 'Armadillo_V800_CheckDisk_best_resources.exe',
 'Armadillo_V700_ftp_better.exe',
 'Armadillo_V800_chglogon_minimal.exe',
 'Armadillo_V700_DpiScaling_best_resources.exe',
 'Armadillo_V700_Bginfo_best.exe',
 'Armadillo_V700_FileAssociation_best_full.exe',
 'Armadillo_V800_DpiScaling_best.exe',
 'Armadillo_V700_Autoruns_best_resources.exe',
 'Armadillo_V700_Desktops_better.exe',
 'Armadillo_V700_ConfigProfile_better.exe',
 'Armadillo_V700_expand_best_full.exe',
 'Armadillo_V800_calc_minimal.exe',
 'Armadillo_V700_Desktops_best_resources.exe',
 'Armadillo_V700_Defrag_better.exe',
 'Armadillo_V700_DiskCleaner_better.exe',
 'Armadillo_V800_chgusr_best.exe',
 'Armadillo_V700_chgport_better.exe',
 'Armadillo_V700_autorunsc_best_resources.exe',
 'Armadillo_V700_cmd_best_full.exe',
 'Armadillo_V700_autorunsc_minimal.exe',
 'Armadillo_V700_Desktops_best_full.exe',
 'Armadillo_V700_cmd_best_resources.exe',
 'Armadillo_V700_checkver_best.exe',
 'Armadillo_V700_chkdsk_minimal.exe',
 'Armadillo_V700_DiskCleaner_best.exe',
 'Armadillo_V700_Coreinfo_minimal.exe',
 'Armadillo_V800_cleanupintlcache_best.exe',
 'Armadillo_V700_chglogon_better.exe',
 'Armadillo_V800_choice_best.exe',
 'Armadillo_V700_Bginfo_better.exe',
 'Armadillo_V700_Autoruns_best_full.exe',
 'Armadillo_V800_eventcreate_best.exe',
 'Armadillo_V800_ComIntRep_better.exe',
 'Armadillo_V800_DriveCleanup_minimal.exe',
 'Armadillo_V800_expand_best_resources.exe',
 'Armadillo_V800_disk2vhd_better.exe',
 'Armadillo_V800_DriveCleanup_best.exe',
 'Armadillo_V700_chgport_best_resources.exe',
 'Armadillo_V700_Clockres_best.exe',
 'Armadillo_V800_ftp_minimal.exe',
 'Armadillo_V800_chkntfs_best.exe',
 'Armadillo_V700_Clockres_best_resources.exe',
 'Armadillo_V700_find_best_full.exe',
 'Armadillo_V800_chgport_minimal.exe',
 'Armadillo_V800_find_best_resources.exe',
 'Armadillo_V700_checkver_best_full.exe',
 'Armadillo_V800_DpiScaling_better.exe',
 'Armadillo_V700_Coreinfo_best.exe',
 'Armadillo_V700_Defrag_minimal.exe',
 'Armadillo_V800_expand_better.exe',
 'Armadillo_V800_calc_best.exe',
 'Armadillo_V800_autorunsc_minimal.exe',
 'Armadillo_V700_find_best_resources.exe',
 'Armadillo_V800_fsquirt_best_resources.exe',
 'Armadillo_V800_DpiScaling_minimal.exe',
 'Armadillo_V700_chkdsk_best_full.exe',
 'Armadillo_V700_ConfigProfile_best_full.exe',
 'Armadillo_V800_expand_minimal.exe',
 'Armadillo_V800_calc_better.exe',
 'Armadillo_V800_accesschk_best.exe',
 'Armadillo_V800_autorunsc_better.exe',
 'Armadillo_V700_fsquirt_minimal.exe',
 'Armadillo_V800_Desktops_best.exe',
 'Armadillo_V700_diagtrackrunner_minimal.exe',
 'Armadillo_V700_chkntfs_best_resources.exe',
 'Armadillo_V800_choice_minimal.exe',
 'Armadillo_V700_csrstub_minimal.exe',
 'Armadillo_V700_diskext_best_resources.exe',
 'Armadillo_V800_diskext_best_resources.exe',
 'Armadillo_V700_eventcreate_better.exe',
 'Armadillo_V800_control_better.exe',
 'Armadillo_V800_find_minimal.exe',
 'Armadillo_V700_accesschk_minimal.exe',
 'Armadillo_V700_CheckDisk_best_full.exe',
 'Armadillo_V800_cmbins_minimal.exe',
 'Armadillo_V800_disk2vhd_minimal.exe',
 'Armadillo_V700_ditrace_best_full.exe',
 'Armadillo_V800_find_best.exe',
 'Armadillo_V700_CheckUpdate_best_full.exe',
 'Armadillo_V700_Defrag_best.exe',
 'Armadillo_V700_CheckUpdate_minimal.exe',
 'Armadillo_V700_du_best_full.exe',
 'Armadillo_V700_dfrgui_best_full.exe',
 'Armadillo_V800_ftp_best.exe',
 'Armadillo_V800_choice_better.exe',
 'Armadillo_V700_chgusr_better.exe',
 'Armadillo_V700_diagtrackrunner_best_full.exe',
 'Armadillo_V700_ExtExport_best_resources.exe',
 'Armadillo_V700_ComIntRep_better.exe',
 'Armadillo_V800_diskext_minimal.exe',
 'Armadillo_V800_chkdsk_best_resources.exe',
 'Armadillo_V800_fc_minimal.exe',
 'Armadillo_V800_Desktops_best_resources.exe',
 'Armadillo_V800_ConfigProfile_better.exe',
 'Armadillo_V700_Desktops_best.exe',
 'Armadillo_V700_diagtrackrunner_best_resources.exe',
 'Armadillo_V800_diagtrackrunner_minimal.exe',
 'Armadillo_V700_chkdsk_better.exe',
 'Armadillo_V800_du_better.exe',
 'Armadillo_V700_Autologon_best_full.exe',
 'Armadillo_V700_ftp_minimal.exe',
 'Armadillo_V800_ExtExport_best_resources.exe',
 'Armadillo_V700_calc_best.exe',
 'Armadillo_V700_Autoruns_better.exe',
 'Armadillo_V800_FileAssociation_better.exe',
 'Armadillo_V800_ConfigProfile_best_resources.exe',
 'Armadillo_V700_dfrgui_best_resources.exe',
 'Armadillo_V800_chgport_best.exe',
 'Armadillo_V800_Autologon_best.exe',
 'Armadillo_V800_CheckUpdate_best_resources.exe',
 'Armadillo_V700_CheckDisk_better.exe',
 'Armadillo_V700_chkntfs_better.exe',
 'Armadillo_V800_cmbins_best.exe',
 'Armadillo_V700_diagtrackrunner_better.exe',
 'Armadillo_V700_find_better.exe',
 'Armadillo_V800_cmd_minimal.exe',
 'Armadillo_V700_du_best.exe',
 'Armadillo_V700_ComIntRep_minimal.exe',
 'Armadillo_V700_cmd_best.exe',
 'Armadillo_V800_Clockres_minimal.exe',
 'Armadillo_V800_autorunsc_best.exe',
 'Armadillo_V800_Autoruns_best.exe',
 'Armadillo_V800_ConfigProfile_best.exe',
 'Armadillo_V800_ExtExport_best.exe',
 'Armadillo_V700_ConfigProfile_best.exe',
 'Armadillo_V700_chgusr_best_resources.exe',
 'Armadillo_V700_Defrag_best_resources.exe',
 'Armadillo_V700_chglogon_best_resources.exe',
 'Armadillo_V700_DiskCleaner_minimal.exe',
 'Armadillo_V700_expand_better.exe',
 'Armadillo_V700_autorunsc_best.exe',
 'Armadillo_V700_cmbins_best_full.exe',
 'Armadillo_V800_CheckDisk_best.exe',
 'Armadillo_V700_control_best_resources.exe',
 'Armadillo_V800_ftp_best_resources.exe',
 'Armadillo_V800_eventcreate_better.exe',
 'Armadillo_V700_eventcreate_minimal.exe',
 'Armadillo_V800_du_minimal.exe',
 'Armadillo_V800_chkdsk_minimal.exe',
 'Armadillo_V700_cmbins_minimal.exe',
 'Armadillo_V700_ComIntRep_best_full.exe',
 'Armadillo_V700_calc_better.exe',
 'Armadillo_V700_ComIntRep_best_resources.exe',
 'Armadillo_V800_checkver_better.exe',
 'Armadillo_V700_DpiScaling_best.exe',
 'Armadillo_V800_Autologon_best_resources.exe',
 'Armadillo_V800_cleanupintlcache_better.exe',
 'Armadillo_V700_Coreinfo_best_full.exe',
 'Armadillo_V800_ditrace_best_resources.exe',
 'Armadillo_V700_ExtExport_best_full.exe',
 'Armadillo_V700_Autologon_minimal.exe',
 'Armadillo_V800_ComIntRep_minimal.exe',
 'Armadillo_V700_ExtExport_minimal.exe',
 'Armadillo_V700_Autologon_better.exe',
 'Armadillo_V800_diagtrackrunner_better.exe',
 'Armadillo_V800_DriveCleanup_better.exe',
 'Armadillo_V700_fsquirt_best.exe',
 'Armadillo_V700_cleanupintlcache_best_full.exe',
 'Armadillo_V800_Defrag_minimal.exe',
 'Armadillo_V700_choice_best.exe',
 'Armadillo_V700_eventcreate_best.exe',
 'Armadillo_V700_du_minimal.exe',
 'Armadillo_V800_Bginfo_minimal.exe',
 'Armadillo_V700_ftp_best.exe',
 'Armadillo_V700_csrstub_best.exe',
 'Armadillo_V800_control_best.exe',
 'Armadillo_V800_CheckUpdate_best.exe',
 'Armadillo_V800_fsquirt_better.exe',
 'Armadillo_V800_Clockres_best.exe',
 'Armadillo_V800_DiskCleaner_best.exe',
 'Armadillo_V700_Autoruns_best.exe',
 'Armadillo_V800_du_best.exe',
 'Armadillo_V800_Defrag_better.exe',
 'Armadillo_V800_CheckDisk_minimal.exe',
 'Armadillo_V700_Bginfo_minimal.exe',
 'Armadillo_V800_DiskCleaner_minimal.exe',
 'Armadillo_V700_cmbins_best.exe',
 'Armadillo_V800_accesschk_better.exe',
 'Armadillo_V800_Autologon_minimal.exe',
 'Armadillo_V800_fc_best_resources.exe',
 'Armadillo_V700_FileAssociation_minimal.exe',
 'Armadillo_V800_DpiScaling_best_resources.exe',
 'Armadillo_V800_Bginfo_best_resources.exe',
 'Armadillo_V700_diskext_best_full.exe',
 'Armadillo_V700_dfrgui_better.exe',
 'Armadillo_V700_ditrace_minimal.exe',
 'Armadillo_V700_disk2vhd_better.exe',
 'Armadillo_V700_dfrgui_minimal.exe',
 'Armadillo_V700_ExtExport_better.exe',
 'Armadillo_V700_expand_best_resources.exe',
 'Armadillo_V800_control_best_resources.exe',
 'Armadillo_V800_Autoruns_minimal.exe',
 'Armadillo_V700_cmbins_better.exe',
 'Armadillo_V800_checkver_best_resources.exe',
 'Armadillo_V800_chgusr_best_resources.exe',
 'Armadillo_V800_diskext_best.exe',
 'Armadillo_V800_choice_best_resources.exe',
 'Armadillo_V800_ditrace_minimal.exe',
 'Armadillo_V800_accesschk_best_resources.exe',
 'Armadillo_V700_choice_better.exe',
 'Armadillo_V700_ComIntRep_best.exe',
 'Armadillo_V700_CheckUpdate_best.exe',
 'Armadillo_V800_chgport_best_resources.exe',
 'Armadillo_V700_DiskCleaner_best_resources.exe',
 'Armadillo_V700_fsquirt_best_full.exe',
 'Armadillo_V700_choice_minimal.exe',
 'Armadillo_V700_fc_minimal.exe',
 'Armadillo_V700_ADInsight_best_resources.exe',
 'Armadillo_V700_accesschk_better.exe',
 'Armadillo_V700_DriveCleanup_best_resources.exe',
 'Armadillo_V800_chglogon_best.exe',
 'Armadillo_V800_ComIntRep_best_resources.exe',
 'Armadillo_V800_eventcreate_minimal.exe',
 'Armadillo_V800_chkdsk_better.exe',
 'Armadillo_V800_ExtExport_minimal.exe',
 'Armadillo_V700_CheckDisk_best_resources.exe',
 'Armadillo_V700_chgport_minimal.exe',
 'Armadillo_V700_DriveCleanup_better.exe',
 'Armadillo_V800_Coreinfo_minimal.exe',
 'Armadillo_V700_ditrace_best_resources.exe',
 'Armadillo_V800_chkntfs_best_resources.exe',
 'Armadillo_V700_Defrag_best_full.exe',
 'Armadillo_V800_diagtrackrunner_best.exe',
 'Armadillo_V800_cmd_better.exe',
 'Armadillo_V800_diagtrackrunner_best_resources.exe',
 'Armadillo_V800_disk2vhd_best_resources.exe',
 'Armadillo_V700_find_best.exe',
 'Armadillo_V800_fsquirt_minimal.exe',
 'Armadillo_V800_control_minimal.exe',
 'Armadillo_V700_Desktops_minimal.exe',
 'Armadillo_V800_dfrgui_best.exe',
 'Armadillo_V700_calc_best_resources.exe',
 'Armadillo_V800_ADInsight_better.exe',
 'Armadillo_V700_diskext_minimal.exe',
 'Armadillo_V700_Autologon_best_resources.exe',
 'Armadillo_V800_Coreinfo_better.exe',
 'Armadillo_V800_Defrag_best.exe',
 'Armadillo_V700_Coreinfo_best_resources.exe',
 'Armadillo_V700_control_best.exe',
 'Armadillo_V700_disk2vhd_best_resources.exe',
 'Armadillo_V800_ftp_better.exe',
 'Armadillo_V700_chglogon_best.exe',
 'Armadillo_V700_dfrgui_best.exe',
 'Armadillo_V700_FileAssociation_better.exe',
 'Armadillo_V700_Clockres_better.exe',
 'Armadillo_V700_cmd_minimal.exe',
 'Armadillo_V700_cmbins_best_resources.exe',
 'Armadillo_V700_fc_best_full.exe',
 'Armadillo_V700_Autoruns_minimal.exe',
 'Armadillo_V800_fc_better.exe',
 'Armadillo_V800_du_best_resources.exe',
 'Armadillo_V800_ComIntRep_best.exe',
 'Armadillo_V700_disk2vhd_best_full.exe',
 'Armadillo_V800_checkver_minimal.exe',
 'Armadillo_V700_diskext_better.exe',
 'Armadillo_V700_find_minimal.exe',
 'Armadillo_V700_ADInsight_minimal.exe',
 'Armadillo_V700_cleanupintlcache_best_resources.exe',
 'Armadillo_V700_eventcreate_best_full.exe',
 'Armadillo_V700_chgusr_best.exe',
 'Armadillo_V800_dfrgui_minimal.exe',
 'Armadillo_V700_accesschk_best.exe',
 'Armadillo_V700_fc_best_resources.exe',
 'Armadillo_V700_disk2vhd_minimal.exe',
 'Armadillo_V800_Bginfo_best.exe',
 'Armadillo_V700_ExtExport_best.exe',
 'Armadillo_V700_chkntfs_best_full.exe',
 'Armadillo_V700_CheckUpdate_best_resources.exe',
 'Armadillo_V700_CheckDisk_best.exe',
 'Armadillo_V700_DpiScaling_better.exe',
 'Armadillo_V700_chglogon_minimal.exe',
 'Armadillo_V700_DiskCleaner_best_full.exe',
 'Armadillo_V800_cleanupintlcache_minimal.exe',
 'Armadillo_V800_Bginfo_better.exe',
 'Armadillo_V700_checkver_best_resources.exe',
 'Armadillo_V800_chgport_better.exe',
 'Armadillo_V700_choice_best_full.exe',
 'Armadillo_V700_ADInsight_best_full.exe',
 'Armadillo_V800_DiskCleaner_best_resources.exe',
 'Armadillo_V700_ditrace_best.exe',
 'Armadillo_V800_eventcreate_best_resources.exe',
 'Armadillo_V800_accesschk_minimal.exe',
 'Armadillo_V800_Clockres_best_resources.exe',
 'Armadillo_V700_autorunsc_better.exe',
 'Armadillo_V700_disk2vhd_best.exe',
 'Armadillo_V700_Bginfo_best_resources.exe',
 'Armadillo_V700_control_minimal.exe',
 'Armadillo_V700_FileAssociation_best.exe',
 'Armadillo_V700_control_best_full.exe',
 'Armadillo_V700_ftp_best_resources.exe',
 'Armadillo_V700_choice_best_resources.exe',
 'Armadillo_V800_cmd_best.exe',
 'Armadillo_V700_csrstub_best_full.exe',
 'Armadillo_V700_autorunsc_best_full.exe',
 'Armadillo_V800_DiskCleaner_better.exe',
 'Armadillo_V700_cleanupintlcache_better.exe',
 'Armadillo_V800_Desktops_better.exe',
 'Armadillo_V800_fc_best.exe',
 'Armadillo_V700_accesschk_best_resources.exe',
 'Armadillo_V800_Coreinfo_best.exe',
 'Armadillo_V800_dfrgui_better.exe',
 'Armadillo_V800_chglogon_best_resources.exe',
 'Armadillo_V800_cmbins_better.exe',
 'Armadillo_V700_chgport_best_full.exe',
 'Armadillo_V700_DpiScaling_minimal.exe',
 'Armadillo_V800_ditrace_best.exe',
 'Armadillo_V700_Clockres_minimal.exe',
 'Armadillo_V700_Bginfo_best_full.exe',
 'Armadillo_V700_ADInsight_best.exe',
 'Armadillo_V800_CheckUpdate_minimal.exe',
 'Armadillo_V800_csrstub_minimal.exe',
 'Armadillo_V700_control_better.exe',
 'Armadillo_V700_ADInsight_better.exe',
 'Armadillo_V700_diagtrackrunner_best.exe',
 'Armadillo_V800_csrstub_best.exe',
 'Armadillo_V700_fc_best.exe',
 'Armadillo_V800_Clockres_better.exe',
 'Armadillo_V800_chkdsk_best.exe',
 'Armadillo_V700_fsquirt_better.exe',
 'Armadillo_V700_eventcreate_best_resources.exe',
 'Armadillo_V700_chglogon_best_full.exe',
 'Armadillo_V700_chkntfs_minimal.exe',
 'Armadillo_V800_Autoruns_best_resources.exe',
 'Armadillo_V700_chgport_best.exe',
 'Armadillo_V700_CheckUpdate_better.exe',
 'Armadillo_V800_chgusr_minimal.exe',
 'Armadillo_V800_ADInsight_minimal.exe',
 'Armadillo_V700_calc_best_full.exe',
 'Armadillo_V700_DriveCleanup_minimal.exe',
 'Armadillo_V800_diskext_better.exe',
 'Armadillo_V700_DriveCleanup_best.exe',
 'Armadillo_V700_expand_best.exe',
 'Armadillo_V700_FileAssociation_best_resources.exe',
 'Armadillo_V700_CheckDisk_minimal.exe',
 'Armadillo_V800_Autologon_better.exe',
 'Armadillo_V800_chkntfs_better.exe',
 'Armadillo_V800_calc_best_resources.exe',
 'Armadillo_V700_csrstub_best_resources.exe',
 'Armadillo_V800_cmd_best_resources.exe',
 'Armadillo_V700_calc_minimal.exe',
 'Armadillo_V800_dfrgui_best_resources.exe',
 'Armadillo_V700_accesschk_best_full.exe',
 'Armadillo_V800_FileAssociation_best.exe',
 'Armadillo_V800_Desktops_minimal.exe',
 'Armadillo_V700_diskext_best.exe',
 'Armadillo_V700_Coreinfo_better.exe',
 'Armadillo_V800_Coreinfo_best_resources.exe',
 'Armadillo_V800_FileAssociation_minimal.exe',
 'Armadillo_V800_ADInsight_best_resources.exe',
 'Armadillo_V800_Defrag_best_resources.exe',
 'Armadillo_V700_chkdsk_best_resources.exe',
 'Armadillo_V800_expand_best.exe',
 'Armadillo_V800_chgusr_better.exe',
 'Armadillo_V700_chgusr_minimal.exe',
 'Armadillo_V800_chglogon_better.exe',
 'Armadillo_V800_FileAssociation_best_resources.exe',
 'Armadillo_V700_DpiScaling_best_full.exe',
 'Armadillo_V800_checkver_best.exe',
 'Armadillo_V800_ConfigProfile_minimal.exe',
 'Armadillo_V700_checkver_better.exe',
 'Armadillo_V800_DriveCleanup_best_resources.exe',
 'Armadillo_V700_expand_minimal.exe',
 'Armadillo_V700_chkdsk_best.exe',
 'Armadillo_V700_Autologon_best.exe',
 'Armadillo_V800_autorunsc_best_resources.exe',
 'Armadillo_V800_ADInsight_best.exe',
 'Armadillo_V700_fc_better.exe',
 'Armadillo_V800_CheckDisk_better.exe',
 'Armadillo_V800_fsquirt_best.exe',
 'Armadillo_V700_chgusr_best_full.exe',
 'Armadillo_V700_du_better.exe',
 'Armadillo_V800_cmbins_best_resources.exe',
 'Armadillo_V800_csrstub_best_resources.exe',
 'Armadillo_V700_du_best_resources.exe',
 'Armadillo_V700_cleanupintlcache_minimal.exe',
 'Armadillo_V800_find_better.exe',
 'Armadillo_V700_ditrace_better.exe',
 'Armadillo_V700_csrstub_better.exe',
 'Armadillo_V700_ConfigProfile_minimal.exe',
 'Armadillo_V700_ConfigProfile_best_resources.exe',
 'Armadillo_V800_chkntfs_minimal.exe',
 'Armadillo_V800_csrstub_better.exe',
 'Armadillo_V700_chkntfs_best.exe',
 'Armadillo_V700_cleanupintlcache_best.exe',
 'Armadillo_V800_disk2vhd_best.exe',
 'PECompact_V3022_disk2vhd_copy.exe',
 'PECompact_V3022_disk2vhd_aplib9.exe',
 'PECompact_V3022_disk2vhd_aplib1_nofastdecoder.exe',
 'PECompact_V3022_disk2vhd_aplib1.exe',
 'PECompact_V3022_disk2vhd_cipher1.exe',
 'PECompact_V3022_disk2vhd_brieflz.exe',
 'PECompact_V3022_disk2vhd_jcalg1.exe',
 'PECompact_V3022_disk2vhd_lzma2.exe',
 'PECompact_V3022_disk2vhd_ffce.exe',
 'PECompact_V3022_disk2vhd_cipher2.exe',
 'PECompact_V3022_disk2vhd_lzma.exe',
 'PECompact_V3022_disk2vhd_expand.exe',
 'PECompact_V3022_disk2vhd_crc32.exe',
 'PECompact_V3022_disk2vhd_inv.exe',
 'PECompact_V3022_disk2vhd_elfhash.exe',
 'PECompact_V3022_disk2vhd_aplib1_exports.exe',
 'PECompact_V3022_disk2vhd_aplib1_checksum.exe',
 'ZProtect_v160_geek_check_packed.exe',
 'ZProtect_v160_geek_default_packed.exe',
 'ZProtect_v160_disk2vhd_protect_calls_packed.exe',
 'ZProtect_v160_disk2vhd_check_packed.exe',
 'ZProtect_v160_disk2vhd_import_packed.exe',
 'ZProtect_v160_disk2vhd_default_packed.exe',
 'ZProtect_v160_geek_protect_calls_packed.exe',
 'ZProtect_v160_geek_import_packed.exe',
 'pelock_V106_dfrgui_compress10_coderedirection.exe',
 'pelock_V106_dxwebsetup_compress10.exe',
 'ASProtect_v23_ADExplorer_good_compress_checksum_packed.exe',
 'ASProtect_v23_ADExplorer_good_compress_packed.exe',
 'ASProtect_v23_Dbgview_good_compress_packed.exe',
 'ASProtect_v23_ADInsight_good_compress_import_packed.exe',
 'ASProtect_v23_ADInsight_good_compress_packed.exe',
 'ASProtect_v23_geek_good_compress_import_packed.exe',
 'ASProtect_v23_Bginfo_good_compress_import_packed.exe',
 'ASProtect_v23_Dbgview_good_compress_resources_packed.exe',
 'ASProtect_v23_Contig_good_compress_resources_packed.exe',
 'ASProtect_v23_geek_good_compress_resources_packed.exe',
 'ASProtect_v23_7za_good_compress_resources_packed.exe',
 'ASProtect_v23_ComIntRep_good_compress_full_packed.exe',
 'ASProtect_v23_cpuz_x32_best_compress_packed.exe',
 'ASProtect_v23_Bginfo_good_compress_full_packed.exe',
 'ASProtect_v23_autorunsc_good_compress_checksum_packed.exe',
 'ASProtect_v23_disk2vhd_good_compress_checksum_packed.exe',
 'ASProtect_v23_adwcleaner_7_good_compress_checksum_packed.exe',
 'ASProtect_v23_Contig_best_compress_packed.exe',
 'ASProtect_v23_cpuz_x32_good_compress_packed.exe',
 'ASProtect_v23_Dbgview_good_compress_import_packed.exe',
 'ASProtect_v23_DiskView_good_compress_packed.exe',
 'ASProtect_v23_Bginfo_good_compress_resources_packed.exe',
 'ASProtect_v23_FastHash_kr_best_compress_packed.exe',
 'ASProtect_v23_cpuz_x32_good_compress_resources_packed.exe',
 'ASProtect_v23_Autoruns_good_compress_full_packed.exe',
 'ASProtect_v23_Autoruns_good_compress_checksum_packed.exe',
 'ASProtect_v23_ADExplorer_best_compress_packed.exe',
 'ASProtect_v23_disk2vhd_best_compress_packed.exe',
 'ASProtect_v23_ComIntRep_good_compress_resources_packed.exe',
 'ASProtect_v23_ComIntRep_best_compress_packed.exe',
 'ASProtect_v23_Autoruns_good_compress_import_packed.exe',
 'ASProtect_v23_autorunsc_good_compress_packed.exe',
 'ASProtect_v23_DiskView_good_compress_full_packed.exe',
 'ASProtect_v23_calc_good_compress_packed.exe',
 'ASProtect_v23_disk2vhd_good_compress_resources_packed.exe',
 'ASProtect_v23_calc_best_compress_packed.exe',
 'ASProtect_v23_ADInsight_good_compress_resources_packed.exe',
 'ASProtect_v23_ADExplorer_good_compress_resources_packed.exe',
 'ASProtect_v23_7zFM_good_compress_import_packed.exe',
 'ASProtect_v23_autorunsc_good_compress_import_packed.exe',
 'ASProtect_v23_7zFM_good_compress_resources_packed.exe',
 'ASProtect_v23_Contig_good_compress_import_packed.exe',
 'ASProtect_v23_adwcleaner_7_good_compress_full_packed.exe',
 'ASProtect_v23_geek_good_compress_checksum_packed.exe',
 'ASProtect_v23_7zFMn_good_compress_packed.exe',
 'ASProtect_v23_geek_good_compress_full_packed.exe',
 'ASProtect_v23_ADExplorer_good_compress_full_packed.exe',
 'ASProtect_v23_disk2vhd_good_compress_full_packed.exe',
 'ASProtect_v23_calc_good_compress_import_packed.exe',
 'ASProtect_v23_disk2vhd_good_compress_import_packed.exe',
 'ASProtect_v23_DiskView_good_compress_import_packed.exe',
 'ASProtect_v23_Bginfo_good_compress_packed.exe',
 'ASProtect_v23_Dbgview_best_compress_packed.exe',
 'ASProtect_v23_7zFMn_good_compress_checksum_packed.exe',
 'ASProtect_v23_cpuz_x32_good_compress_import_packed.exe',
 'ASProtect_v23_Everything_good_compress_checksum_packed.exe',
 'ASProtect_v23_7za_good_compress_packed.exe',
 'ASProtect_v23_geek_best_compress_packed.exe',
 'ASProtect_v23_Contig_good_compress_packed.exe',
 'ASProtect_v23_autorunsc_best_compress_packed.exe',
 'ASProtect_v23_Autoruns_good_compress_resources_packed.exe',
 'ASProtect_v23_7za_good_compress_full_packed.exe',
 'ASProtect_v23_cpuz_x32_good_compress_full_packed.exe',
 'ASProtect_v23_FastHash_kr_good_compress_import_packed.exe',
 'ASProtect_v23_autorunsc_good_compress_full_packed.exe',
 'ASProtect_v23_DiskView_good_compress_checksum_packed.exe',
 'ASProtect_v23_calc_good_compress_resources_packed.exe',
 'ASProtect_v23_Everything_good_compress_packed.exe',
 'ASProtect_v23_Bginfo_good_compress_checksum_packed.exe',
 'ASProtect_v23_7za_good_compress_import_packed.exe',
 'ASProtect_v23_disk2vhd_good_compress_packed.exe',
 'ASProtect_v23_FastHash_kr_good_compress_checksum_packed.exe',
 'ASProtect_v23_adwcleaner_7_good_compress_resources_packed.exe',
 'ASProtect_v23_Autoruns_best_compress_packed.exe',
 'ASProtect_v23_7za_good_compress_checksum_packed.exe',
 'ASProtect_v23_7zFMn_best_compress_packed.exe',
 'ASProtect_v23_Contig_good_compress_full_packed.exe',
 'ASProtect_v23_FastHash_kr_good_compress_resources_packed.exe',
 'ASProtect_v23_Everything_good_compress_resources_packed.exe',
 'ASProtect_v23_7zFM_good_compress_packed.exe',
 'ASProtect_v23_Dbgview_good_compress_checksum_packed.exe',
 'ASProtect_v23_autorunsc_good_compress_resources_packed.exe',
 'ASProtect_v23_calc_good_compress_checksum_packed.exe',
 'ASProtect_v23_ComIntRep_good_compress_checksum_packed.exe',
 'ASProtect_v23_FastHash_kr_good_compress_packed.exe',
 'ASProtect_v23_geek_good_compress_packed.exe',
 'ASProtect_v23_Dbgview_good_compress_full_packed.exe',
 'ASProtect_v23_DiskView_good_compress_resources_packed.exe',
 'ASProtect_v23_DiskView_best_compress_packed.exe',
 'ASProtect_v23_7zFM_best_compress_packed.exe',
 'ASProtect_v23_7zFM_good_compress_full_packed.exe',
 'ASProtect_v23_Everything_best_compress_packed.exe',
 'ASProtect_v23_FastHash_kr_good_compress_full_packed.exe',
 'ASProtect_v23_adwcleaner_7_good_compress_import_packed.exe',
 'ASProtect_v23_adwcleaner_7_good_compress_packed.exe',
 'ASProtect_v23_7zFMn_good_compress_full_packed.exe',
 'ASProtect_v23_calc_good_compress_full_packed.exe',
 'ASProtect_v23_Bginfo_best_compress_packed.exe',
 'ASProtect_v23_adwcleaner_7_best_compress_packed.exe',
 'ASProtect_v23_ADExplorer_good_compress_import_packed.exe',
 'ASProtect_v23_ADInsight_good_compress_full_packed.exe',
 'ASProtect_v23_Contig_good_compress_checksum_packed.exe',
 'ASProtect_v23_7zFMn_good_compress_resources_packed.exe',
 'ASProtect_v23_7zFMn_good_compress_import_packed.exe',
 'ASProtect_v23_ComIntRep_good_compress_packed.exe',
 'ASProtect_v23_cpuz_x32_good_compress_checksum_packed.exe',
 'ASProtect_v23_ADInsight_best_compress_packed.exe',
 'ASProtect_v23_Autoruns_good_compress_packed.exe',
 'ASProtect_v23_Everything_good_compress_import_packed.exe',
 'ASProtect_v23_7zFM_good_compress_checksum_packed.exe',
 'ASProtect_v23_7za_best_compress_packed.exe',
 'ASProtect_v23_ADInsight_good_compress_checksum_packed.exe',
 'ASProtect_v23_Everything_good_compress_full_packed.exe',
 'ASProtect_v23_ComIntRep_good_compress_import_packed.exe']

not_extracted_packgenome_lpd1 = ['neolite_neo_PAGEANT_32.EXE', 'neolite_neo_PSCP_32.EXE']

not_extracted_packgenome_rgd = []

not_extracted_rgd1 = ['neolite_neo_ADExplorer.exe']

not_extracted_packware = ['upx_a81362b3427e0b8061a937245cff720c32e19a0f.upx.bin', 'upx_9bbfb7e070238e88107b8335190500b6d29bc80d.upx.bin', 'themida-v2_d756de22a8172c1560299ef3146e6c060fba210e.themida-v2.bin', 'themida-v2_b47c2247999b3d45297803313b598b17b544576f.themida-v2.bin', 'telock_7a3a873e5e940c04d11806d2bb874b03d140206f.telock.bin', 'telock_f9fb1623e84b55df84e987f28914756371a5ae37.telock.bin', 'upx_bb7b1bd42a3282a075a0ff61118f4cd0185c9434.upx.bin', 'petite_30058ff28fa1b96e9354285dd2a9eaa617d2d822.petite.bin', 'pecompact_a63e34ec6e7610352cce4cc2eea3ea164eb27bfc.pecompact.bin', 'telock_90dcdae6e283bc401f61ee75c7052ec80a713532.telock.bin']

not_extracted_outliers = ['enigmavb_powerMAX_x32.exe', 'enigmavb_pywin32-221.win32-py2.7.exe', 'enigmavb_Start_Here_Win.exe']

not_extracted_notpacked = ['PEViewer.exe', 'calc.exe', 'Autoruns.exe', 'PSCP_32.EXE', 'Contig.exe', '7zFM.exe', '7zFMn.exe', 'sigcheck.exe', 'Procmon.exe', 'disk2vhd.exe', 'portmon.exe', 'PAGEANT_32.EXE', 'Everything.exe', 'procdump.exe', 'Tcpview.exe', 'RAMMap.exe', 'ADInsight.exe', 'psping.exe', 'geek.exe', 'ADExplorer.exe', 'Hasher.exe', 'mmc.exe', 'HWMonitorPro_x32.exe', '7za.exe', 'autorunsc.exe', 'PUTTYGEN_32.EXE', 'FastHash_kr.exe', 'PUTTY_32.EXE', 'procexp.exe', 'adwcleaner_7.2.4.0.exe', 'Sysmon.exe', 'PLINK_32.EXE', 'ComIntRep.exe', 'PortableWinCDEmu-4.0.exe', 'DiskView.exe', 'HDDScan.exe', 'cpuz_x32.exe', 'PSFTP_32.EXE', 'Dbgview.exe', 'md5summer.exe', 'HashCalc.exe', 'grepWin-1.9.0_portable.exe', 'Bginfo.exe', 'puttytel_32.exe', 'Listdlls.exe']

# %%
len(not_extracted_packgenome_lpd)
# Out:
# 552

# %%
len(not_extracted_packgenome_lpd1)
# Out:
# 2

# %%
len(not_extracted_outliers)
# Out:
# 3

# %%
len(not_extracted_packgenome_rgd)
# Out:
# 0

# %%
packer_not_extracted_lpd = [x.split('_')[0] for x in not_extracted_packgenome_lpd]
Counter(packer_not_extracted_lpd)
# Out:
# Counter({'Themida': 13,
#          'VMProtect': 2,
#          'Armadillo': 396,
#          'PECompact': 17,
#          'ZProtect': 8,
#          'pelock': 2,
#          'ASProtect': 114})

# %%
packer_not_extracted_lpd1 = [x.split('_')[0] for x in not_extracted_packgenome_lpd1]
Counter(packer_not_extracted_lpd1)
# Out:
# Counter({'neolite': 2})

# %%
packer_not_extracted_outliers = [x.split('_')[0] for x in not_extracted_outliers]
Counter(packer_not_extracted_outliers)
# Out:
# Counter({'enigmavb': 3})

# %%
len(not_extracted_notpacked)
# Out:
# 45
